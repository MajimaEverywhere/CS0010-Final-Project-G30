# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
fire = pd.read_csv("fireIncidents.csv", index_col = "call_no")
fire["neighborhood"].value_counts().sort_values(ascending=True)
# Out:
# Mount Oliver Borough           6
# Regent Square                  7
# Mt. Oliver                    10
# East Carnegie                 10
# St. Clair                     11
#                             ...
# Hazelwood                    213
# South Side Flats             219
# Central Business District    225
# Squirrel Hill South          225
# Carrick                      255
# Name: neighborhood, Length: 91, dtype: int64

# %%
neighborhood = fire
neighborhood["neighborhood"].value_counts()
neighborhood["alarms"].value_counts().sort_index().plot(kind = 'pie')
fire["alarms"].value_counts(1)
# Out:
# 1     0.514010
# 0     0.449407
# 2     0.020678
# 3     0.011012
# 4     0.003426
# 5     0.001101
# 19    0.000122
# 7     0.000122
# 6     0.000122
# Name: alarms, dtype: float64

# %%
fire_data = pd.read_csv("fireIncidents.csv", index_col="call_no")
query_mask = fire_data['neighborhood'] == "North Oakland"
query_mask.head()
Fire = fire_data[query_mask]
Fire.head(5)
# Out:
#             incident_type                             type_description  \
# call_no
# F130087678          113.0          Cooking fire, confined to container
# F130089273          112.0  Fires in structure other than in a building
# F140007786          113.0          Cooking fire, confined to container
# F150028622          118.0             Trash or rubbish fire, contained
# F150035024          140.0               Natural vegetation fire, Other
#
#                                                     address  \
# call_no
# F130087678        300 BLOCK N CRAIG ST, PITTSBURGH PA 15213
# F130089273     3800 BLOCK BIGELOW BLVD, PITTSBURGH PA 15201
# F140007786       4400 BLOCK CENTRE AVE, PITTSBURGH PA 15213
# F150028622       HENRY ST & S CRAIG ST, PITTSBURGH PA 15213
# F150035024  3800 BLOCK UNIVERSITY C DR, PITTSBURGH PA 15213
#
#                      alarm_time  alarms primary_unit  census_tract  \
# call_no
# F130087678  2013-12-08T19:23:40       1      231EN06         507.0
# ...

# %%
fire.pivot(columns="neighborhood", values="alarms").head(5)
# Out:
# neighborhood  NaN  Allegheny Center  Allegheny West  Allentown  Arlington  \
# call_no
# F13-0020288   NaN               NaN             NaN        NaN        NaN
# F13-0025726   NaN               NaN             NaN        NaN        NaN
# F130000539    NaN               NaN             NaN        NaN        NaN
# F130000714    NaN               NaN             NaN        NaN        NaN
# F130000772    NaN               NaN             NaN        NaN        NaN
#
# neighborhood  Arlington Heights  Banksville  Bedford Dwellings  Beechview  \
# call_no
# F13-0020288                 NaN         NaN                NaN        NaN
# F13-0025726                 NaN         NaN                NaN        NaN
# F130000539                  NaN         NaN                NaN        NaN
# F130000714                  NaN         NaN                NaN        NaN
# F130000772                  NaN         NaN                NaN        NaN
#
# ...
