# %% [markdown]
# #Introduction
# The dataset I looked at was Fire Incidents. The reason I chose fire incidents as my dataset is because I feel that safety is a major part of deciding what makes a neighborhood good and bad. If a neighborhood has a lot of fires, I would not want to live in that area. The most important factor when deciding a neighborhood should be safety as a whole.

# %%
## importing pandas, numpy, and matplot
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
## reading the file
df = pd.read_csv("fireIncidents.csv", index_col = "call_no")

# %%
## looking at which neighborhood has the lowest amount of fire incidents and which neighborhood has the most
fireIncidents = df["neighborhood"].value_counts().sort_values(ascending=True)
fireIncidents
# Out:
# Mount Oliver Borough           6
# Regent Square                  7
# East Carnegie                 10
# Mt. Oliver                    10
# St. Clair                     11
#                             ...
# Hazelwood                    213
# South Side Flats             219
# Central Business District    225
# Squirrel Hill South          225
# Carrick                      255
# Name: neighborhood, Length: 91, dtype: int64

# %%
## displaying 
df["neighborhood"].value_counts().sort_index().plot(kind = 'bar')

# %%
##Finding percentage of fires that do not occur in a building
neighborhood = df
neighborhood["neighborhood"].value_counts()
neighborhood["alarms"].value_counts().sort_index().plot(kind = 'pie')
fire["alarms"].value_counts(1)
##Display the percentages in a pie chart
# Out:
# 1     0.514010
# 0     0.449407
# 2     0.020678
# 3     0.011012
# 4     0.003426
# 5     0.001101
# 19    0.000122
# 7     0.000122
# 6     0.000122
# Name: alarms, dtype: float64

# %%
#Sampling Mount Oliver Borough to see how many fires were in a building
fire_data = pd.read_csv("fireIncidents.csv", index_col="call_no")
query_mask = fire_data['neighborhood'] == "Mount Oliver Borough"
query_mask.head()
Fire = fire_data[query_mask]
Fire.head(6)
# Out:
#             incident_type                        type_description  \
# call_no
# F150054723          111.0                           Building fire
# F140031468          151.0    Outside rubbish, trash or waste fire
# F140034532          132.0  Road freight or transport vehicle fire
# F190084205          151.0    Outside rubbish, trash or waste fire
# F200014168          150.0             Outside rubbish fire, Other
# F200020853          111.0                           Building fire
#
#                                                    address  \
# call_no
# F150054723   1600 BLOCK ARLINGTON AVE, PITTSBURGH PA 15210
# F140031468      600 BLOCK OTTILLIA ST, PITTSBURGH PA 15210
# F140034532      600 BLOCK OTTILLIA ST, PITTSBURGH PA 15210
# F190084205   1700 BLOCK ARLINGTON AVE, PITTSBURGH PA 15210
# F200014168  S 18TH ST & ARLINGTON AVE, PITTSBURGH PA 15210
# F200020853   1700 BLOCK ARLINGTON AVE, PITTSBURGH PA 15210
#
# ...

# %%
#Sampling Regent Square to see how many fires were in a building
query_mask = fire_data['neighborhood'] == "Regent Square"
query_mask.head()
Fire1 = fire_data[query_mask]
Fire1.head(7)
# Out:
#             incident_type                       type_description  \
# call_no
# F130092183          150.0            Outside rubbish fire, Other
# F160040719          160.0            Special outside fire, Other
# F160050286          151.0   Outside rubbish, trash or waste fire
# F150095213          111.0                          Building fire
# F130053860          113.0    Cooking fire, confined to container
# F130084185          131.0                 Passenger vehicle fire
# F210048983          130.0  Mobile property (vehicle) fire, Other
#
#                                                      address  \
# call_no
# F130092183  FORBES AVE & S BRADDOCK AVE, PITTSBURGH PA 15218
# F160040719  FORBES AVE & S BRADDOCK AVE, PITTSBURGH PA 15221
# F160050286         800 BLOCK E END AVE, WILKINSBURG PA 15221
# F150095213     900 BLOCK N BRADDOCK AVE, PITTSBURGH PA 15208
# F130053860     900 BLOCK N BRADDOCK AVE, PITTSBURGH PA 15208
# ...

# %% [markdown]
# #Limitations
# The limitations in this datset were not overly present. The data was relatively straightforward but one main limitation I found was that some of the data was not assigned to a neighborhood. This makes the data not 100% accurate which is slightly annoying but for the most part, it is accurate. This could change the data greatly if every incident had been reported to a correct neighborhood.

# %% [raw]
# #Conclusion
# The neighborhood that I decided is the safest to live in is Mount Oliver Borough. This neighborhood only had 6 fire related incidents and only two of them took place in a building. The reason I chose to only look at fires that happened inside instead all fires is because the value of a fire happening in a building is greater than a fire on the street or in a car. While these fires are all dangerous, a house or building fire can be far more severe in terms of damage and overall safety.
# The neighborhood that is the least safe is a tie between Carrick, Squirrel Hill South, and the Central Business District. They all have 225 total incidents each making them very prone to having fire related incidents often.
