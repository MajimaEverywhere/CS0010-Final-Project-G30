# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
criminals = pd.read_csv("CitationForm2.tsv", sep="\t")
crimeRate = criminals
crimeRate = crimeRate[crimeRate['OFFENSES'].str.contains("5505", na = False)]
crimeRate = crimeRate.groupby("NEIGHBORHOOD").filter(filter_less_than, threshold = 100)
crimeRate["NEIGHBORHOOD"].value_counts().sort_index().plot(kind = 'bar')

# %%
indecent = criminals
indecent = indecent[indecent['OFFENSES'].str.contains("5503", na = False)]
indecent= indecent.groupby("NEIGHBORHOOD").filter(filter_less_than, threshold = 100)
indecent ["NEIGHBORHOOD"].value_counts().sort_index().plot(kind = 'bar')

# %%
ds3 = criminals
ds3 = ds3[ds3['OFFENSES'].str.contains("601.16", na = False)]
ds3= ds3.groupby("NEIGHBORHOOD").filter(filter_less_than, threshold = 10)
ds3["NEIGHBORHOOD"].value_counts().sort_index().plot(kind = 'bar')
